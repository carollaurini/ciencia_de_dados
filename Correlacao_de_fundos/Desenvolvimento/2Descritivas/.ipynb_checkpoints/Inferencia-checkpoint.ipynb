# %%
import pandas as pd
import sklearn 
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import numpy as np
from sklearn import feature_selection
import seaborn as sns
import scipy.stats
from matplotlib import pyplot as plt
import math
import openpyxl
from  matplotlib.colors import LinearSegmentedColormap
import seaborn as sns
import xlsxwriter
from sklearn import feature_selection
from scipy.stats import t

# %%
#Fundo a ser analisado
nome_da_base = 'Book1'#'book_pagaya_riverview'
col_fundos_input = ['JPEIGLSP Index','BRL Curncy','CAD Curncy','AUD Curncy']#['Pagaya Opportunity Fund','Riverview ALF']
nome_benchmark = 'DXY Index'#"IBOXHY Index"
diaria=0
tempo = 12 #252
const = 0.03
df=pd.read_csv('P:\\ciencia_de_dados\\Correlacao_de_fundos\\Desenvolvimento\\1DataPrep\\base_'+ nome_da_base + '.csv',sep =';',index_col=0,decimal=',')

if diaria==1:
    df_diaria = pd.read_csv('P:\\ciencia_de_dados\\Correlacao_de_fundos\\Desenvolvimento\\1DataPrep\\base_'+ nome_benchmark + '.csv',sep =';',index_col=0,decimal=',')
    df = pd.concat([df_diaria, df])

# %%
df.sort_values(by=["Product",'data'],ascending=True,inplace=True)

# %%
df
# Out:
#            data         Product  FinancialPrice   MesAno Mes_nomial  Mes  \
# 484  2011-09-30      AUD Curncy          0.9662  09-2011        Sep    9
# 485  2011-10-31      AUD Curncy          1.0530  10-2011        Oct   10
# 486  2011-11-30      AUD Curncy          1.0283  11-2011        Nov   11
# 487  2011-12-30      AUD Curncy          1.0209  12-2011        Dec   12
# 488  2012-01-31      AUD Curncy          1.0621  01-2012        Jan    1
# ..          ...             ...             ...      ...        ...  ...
# 237  2021-05-31  JPEIGLSP Index        306.6900  05-2021        May    5
# 238  2021-06-30  JPEIGLSP Index        312.5000  06-2021        Jun    6
# 239  2021-07-30  JPEIGLSP Index        325.0200  07-2021        Jul    7
# 240  2021-08-31  JPEIGLSP Index        313.0100  08-2021        Aug    8
# 241  2021-09-30  JPEIGLSP Index        324.3700  09-2021        Sep    9
#
#       Ano  Retorno_1   Retorno
# 484  2011   1.089837  0.089836
# 485  2011   0.976543 -0.023457
# 486  2011   0.992804 -0.007196
# 487  2011   1.040357  0.040357
# 488  2012   1.010451  0.010451
# ..    ...        ...       ...
# 237  2021   1.018944  0.018944
# 238  2021   1.040064  0.040064
# 239  2021   0.963048 -0.036951
# 240  2021   1.036293  0.036293
# 241  2021        NaN       NaN
#
# [726 rows x 9 columns]

# %%
df_sub = df.pivot(index=["data","Ano","Mes"], columns="Product", values="Retorno_1")
df_sub = df_sub.reset_index()
df_sub = df_sub.dropna()

# %%
df_sub
# Out:
# Product        data   Ano  Mes  AUD Curncy  BRL Curncy  CAD Curncy  CRY Index  \
# 0        2011-09-30  2011    9    1.089837    0.912946    0.952871   1.072749
# 1        2011-10-31  2011   10    0.976543    1.054089    1.016587   0.981178
# 2        2011-11-30  2011   11    0.992804    1.032237    1.003833   0.972851
# 3        2011-12-30  2011   12    1.040357    0.935719    0.981690   1.022961
# 4        2012-01-31  2012    1    1.010451    0.983169    0.987333   1.032404
# ..              ...   ...  ...         ...         ...         ...        ...
# 115      2021-04-30  2021    4    1.002333    0.959729    0.981851   1.029741
# 116      2021-05-31  2021    5    0.969485    0.952080    1.027686   1.037368
# 117      2021-06-30  2021    6    0.979461    1.048803    1.006211   1.021991
# 118      2021-07-30  2021    7    0.996187    0.988429    1.011303   1.000404
# 119      2021-08-31  2021    8    0.987835    1.056647    1.005073   1.049303
#
# Product  DXY Index  JPEIGLSP Index
# 0         0.969613        0.842503
# 1         1.029121        1.054936
# 2         1.022887        1.031676
# 3         0.988900        0.966904
# 4         0.993051        0.865463
# ..             ...             ...
# 115       0.984104        0.979934
# 116       1.029022        1.018944
# 117       0.997166        1.040064
# 118       1.004904        0.963048
# 119       1.017317        1.036293
#
# [120 rows x 9 columns]

# %%
df_sub
# Out:
# Product        data   Ano  Mes  AUD Curncy  BRL Curncy  CAD Curncy  CRY Index  \
# 0        2011-09-30  2011    9    1.089837    0.912946    0.952871   1.072749
# 1        2011-10-31  2011   10    0.976543    1.054089    1.016587   0.981178
# 2        2011-11-30  2011   11    0.992804    1.032237    1.003833   0.972851
# 3        2011-12-30  2011   12    1.040357    0.935719    0.981690   1.022961
# 4        2012-01-31  2012    1    1.010451    0.983169    0.987333   1.032404
# ..              ...   ...  ...         ...         ...         ...        ...
# 115      2021-04-30  2021    4    1.002333    0.959729    0.981851   1.029741
# 116      2021-05-31  2021    5    0.969485    0.952080    1.027686   1.037368
# 117      2021-06-30  2021    6    0.979461    1.048803    1.006211   1.021991
# 118      2021-07-30  2021    7    0.996187    0.988429    1.011303   1.000404
# 119      2021-08-31  2021    8    0.987835    1.056647    1.005073   1.049303
#
# Product  DXY Index  JPEIGLSP Index
# 0         0.969613        0.842503
# 1         1.029121        1.054936
# 2         1.022887        1.031676
# 3         0.988900        0.966904
# 4         0.993051        0.865463
# ..             ...             ...
# 115       0.984104        0.979934
# 116       1.029022        1.018944
# 117       0.997166        1.040064
# 118       1.004904        0.963048
# 119       1.017317        1.036293
#
# [120 rows x 9 columns]

# %%
col_fundos1 =col_fundos_input
col_fundos1.append(nome_benchmark)

corr = df_sub[col_fundos_input].corr()

col_fundos1 =col_fundos_input
ax = sns.heatmap(
    corr,
    annot=True, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
plt.savefig('CorrelationMatrix.png',dpi=200)

# %%
x1 = 'BRL Curncy'
x2 = 'JPEIGLSP Index'

# %%
coef_b=[]
coef_s=[]
coef_out_of_sample=[]
data=[]

janela_target=12

def func(df,k):
    n1=30
    df_rand = df[k:60+k].sample(n = n1)
    return scipy.stats.pearsonr(df_rand[x1], df_rand[x2])[0]
   
for k in range(0,len(df_sub[x1])-(61+janela_target)):
    
    #Correlacao Simples lag de 24  Meses passados
    coef_s.append(scipy.stats.pearsonr(df_sub[x1][k+36: k+(36+24)], df_sub[x2][k+36:k+60])[0])
    #Correlacao Futura de 12 Meses
    coef_out_of_sample.append(scipy.stats.pearsonr(df_sub[x1][k+61:k+61+janela_target], df_sub[x2][k+61:k+61+janela_target])[0])
    #Correlacao Bootstrap lag de 5 anos passados
    coef_b.append(np.mean([func(df_sub,k) for i in range(1000)]))
    data.append(df_sub['data'].iloc[60+k:61+k].values[0])
    
df_teste = pd.DataFrame(
    {'mes':data,
    'Correlacao_futura_out_of_sample': coef_out_of_sample,
     'Correlacao_BoostStrapping': coef_b,
     'Correlacao_simples_24_meses': coef_s,
     
    })
df_teste['Correlacao_BoostStrapping_erro'] = df_teste.Correlacao_futura_out_of_sample - df_teste.Correlacao_BoostStrapping
df_teste['Correlacao_Simples_24_meses_erro'] = df_teste.Correlacao_futura_out_of_sample - df_teste.Correlacao_simples_24_meses

# %%
df_teste
# Out:
#            mes  Correlacao_futura_out_of_sample  Correlacao_BoostStrapping  \
# 0   2016-09-30                         0.710098                   0.524896
# 1   2016-10-31                         0.480173                   0.488996
# 2   2016-11-30                         0.356035                   0.492284
# 3   2016-12-30                         0.446196                   0.494076
# 4   2017-01-31                         0.426189                   0.498170
# 5   2017-02-28                         0.447472                   0.495716
# 6   2017-03-31                         0.534403                   0.511277
# 7   2017-04-28                         0.655354                   0.516466
# 8   2017-05-31                         0.679654                   0.502530
# 9   2017-06-30                         0.799142                   0.504022
# 10  2017-07-31                         0.851653                   0.509458
# 11  2017-08-31                         0.824493                   0.516880
# 12  2017-09-29                         0.463044                   0.514589
# 13  2017-10-31                         0.479515                   0.504087
# 14  2017-11-30                         0.480540                   0.518118
# 15  2017-12-29                         0.558186                   0.514076
# 16  2018-01-31                         0.517944                   0.528760
# 17  2018-02-28                         0.520611                   0.535877
# 18  2018-03-30                         0.532167                   0.535052
# 19  2018-04-30                         0.453218                   0.530055
# 20  2018-05-31                         0.443644                   0.536642
# 21  2018-06-29                         0.408332                   0.541732
# 22  2018-07-31                         0.354093                   0.552990
# 23  2018-08-31                         0.357247                   0.564902
# 24  2018-09-28                         0.748595                   0.554286
# 25  2018-10-31                         0.644704                   0.497914
# 26  2018-11-30                         0.718829                   0.497364
# 27  2018-12-31                         0.703246                   0.502877
# 28  2019-01-31                         0.682126                   0.544269
# 29  2019-02-28                         0.855439                   0.530035
# 30  2019-03-29                         0.822844                   0.520229
# 31  2019-04-30                         0.852466                   0.516847
# 32  2019-05-31                         0.846950                   0.516529
# 33  2019-06-28                         0.831221                   0.517645
# 34  2019-07-31                         0.824474                   0.518233
# 35  2019-08-30                         0.821319                   0.542552
# 36  2019-09-30                         0.833094                   0.527835
# 37  2019-10-31                         0.838886                   0.532886
# 38  2019-11-29                         0.841304                   0.505798
# 39  2019-12-31                         0.830721                   0.520857
# 40  2020-01-31                         0.832986                   0.557530
# 41  2020-02-28                         0.641350                   0.596052
# 42  2020-03-31                         0.618318                   0.679148
# 43  2020-04-30                         0.603159                   0.658152
# 44  2020-05-29                         0.507676                   0.659564
# 45  2020-06-30                         0.533702                   0.657844
# 46  2020-07-31                         0.657038                   0.669772
#
#     Correlacao_simples_24_meses  Correlacao_BoostStrapping_erro  \
# 0                      0.475074                        0.185203
# 1                      0.470182                       -0.008823
# 2                      0.479573                       -0.136249
# 3                      0.504142                       -0.047880
# 4                      0.554044                       -0.071981
# 5                      0.672027                       -0.048244
# 6                      0.707109                        0.023125
# 7                      0.679275                        0.138888
# 8                      0.683601                        0.177124
# 9                      0.709585                        0.295120
# 10                     0.699580                        0.342195
# 11                     0.677861                        0.307613
# 12                     0.590354                       -0.051544
# 13                     0.605043                       -0.024573
# 14                     0.601668                       -0.037578
# 15                     0.590180                        0.044111
# 16                     0.677059                       -0.010816
# 17                     0.666225                       -0.015266
# 18                     0.579226                       -0.002886
# 19                     0.577347                       -0.076837
# 20                     0.619226                       -0.092998
# 21                     0.699116                       -0.133400
# 22                     0.732424                       -0.198897
# 23                     0.798515                       -0.207655
# 24                     0.765048                        0.194308
# 25                     0.523855                        0.146790
# 26                     0.513299                        0.221465
# 27                     0.479427                        0.200369
# 28                     0.547090                        0.137857
# 29                     0.509502                        0.325405
# 30                     0.514115                        0.302615
# 31                     0.525404                        0.335620
# 32                     0.503777                        0.330421
# 33                     0.517421                        0.313576
# 34                     0.533915                        0.306242
# 35                     0.568107                        0.278767
# 36                     0.565517                        0.305258
# 37                     0.584378                        0.305999
# 38                     0.543392                        0.335505
# 39                     0.579866                        0.309864
# 40                     0.586775                        0.275457
# 41                     0.587893                        0.045298
# 42                     0.736357                       -0.060830
# 43                     0.725374                       -0.054992
# 44                     0.732746                       -0.151888
# 45                     0.724039                       -0.124141
# 46                     0.720870                       -0.012734
#
#     Correlacao_Simples_24_meses_erro
# 0                           0.235025
# 1                           0.009991
# 2                          -0.123537
# 3                          -0.057946
# 4                          -0.127856
# 5                          -0.224555
# 6                          -0.172706
# 7                          -0.023921
# 8                          -0.003948
# 9                           0.089557
# 10                          0.152073
# 11                          0.146632
# 12                         -0.127310
# 13                         -0.125529
# 14                         -0.121128
# 15                         -0.031993
# 16                         -0.159115
# 17                         -0.145614
# 18                         -0.047059
# 19                         -0.124129
# 20                         -0.175582
# 21                         -0.290784
# 22                         -0.378331
# 23                         -0.441268
# 24                         -0.016454
# 25                          0.120849
# 26                          0.205530
# 27                          0.223819
# 28                          0.135036
# 29                          0.345938
# 30                          0.308729
# 31                          0.327062
# 32                          0.343173
# 33                          0.313800
# 34                          0.290559
# 35                          0.253212
# 36                          0.267576
# 37                          0.254508
# 38                          0.297912
# 39                          0.250855
# 40                          0.246211
# 41                          0.053458
# 42                         -0.118039
# 43                         -0.122215
# 44                         -0.225070
# 45                         -0.190337
# 46                         -0.063832

# %%
sum((df_teste.Correlacao_BoostStrapping_erro)**2) / len(df_teste.Correlacao_BoostStrapping_erro)
# Out:
# 0.04063973905434107

# %%
sum((df_teste.Correlacao_Simples_24_meses_erro)**2) / len(df_teste.Correlacao_BoostStrapping_erro)
# Out:
# 0.04409300940770134

# %%
g =sns.scatterplot(df_teste.mes,df_teste.Correlacao_futura_out_of_sample)
plt.xticks(rotation=90)
plt.tight_layout()
plt.grid() 
g.set(ylim=(-1, 1))
for label in g.get_xaxis().get_ticklabels()[::2]:
    label.set_visible(False)

figure = g.get_figure()  
figure.savefig('0.png',dpi=200)
# Out:
# C:\Users\ana.carolina\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g =sns.scatterplot(df_teste.mes,df_teste.Correlacao_BoostStrapping)
plt.xticks(rotation=90)
plt.tight_layout()
plt.grid() 
g.set(ylim=(-1, 1))
for label in g.get_xaxis().get_ticklabels()[::2]:
    label.set_visible(False)
    
np.mean(df_teste.Correlacao_BoostStrapping)
figure = g.get_figure()  
figure.savefig('1.png',dpi=200)
# Out:
# C:\Users\ana.carolina\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g =sns.scatterplot(df_teste.mes,df_teste.Correlacao_BoostStrapping_erro,color='red')
plt.xticks(rotation=90)
plt.tight_layout()
plt.grid() 
g.set(ylim=(-1, 1))
for label in g.get_xaxis().get_ticklabels()[::2]:
    label.set_visible(False)
np.mean(df_teste.Correlacao_BoostStrapping)
figure = g.get_figure()  
figure.savefig('2.png',dpi=200)
# Out:
# C:\Users\ana.carolina\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g =sns.scatterplot(df_teste.mes,df_teste.Correlacao_simples_24_meses)
plt.xticks(rotation=90)
plt.tight_layout()
plt.grid() 
g.set(ylim=(-1, 1))
for label in g.get_xaxis().get_ticklabels()[::2]:
    label.set_visible(False)
np.mean(df_teste.Correlacao_simples_24_meses)
figure = g.get_figure()  
figure.savefig('3.png',dpi=200)
# Out:
# C:\Users\ana.carolina\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
g =sns.scatterplot(df_teste.mes,df_teste.Correlacao_Simples_24_meses_erro,color='red')
plt.xticks(rotation=90)
plt.tight_layout()
plt.grid() 
g.set(ylim=(-1, 1))
for label in g.get_xaxis().get_ticklabels()[::2]:
    label.set_visible(False)
np.mean(df_teste.Correlacao_BoostStrapping)
figure = g.get_figure()  
figure.savefig('4.png',dpi=200)
# Out:
# C:\Users\ana.carolina\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x= [func(df_sub,len(df_teste.Correlacao_BoostStrapping)) for i in range(1000)]
sns.histplot(x)
confidence_interval = scipy.stats.t.interval(0.95, 999, np.mean(x), np.std(x))
print(np.mean(x),np.std(x),confidence_interval)
plt.savefig('5.png')
# Out:
# 0.6612244385476479 0.10407094762502292 (0.4570017031236178, 0.865447173971678)

# %%
sns.histplot(df_teste.Correlacao_simples_24_meses,bins=20)
# Out:
# <AxesSubplot:xlabel='Correlacao_simples_24_meses', ylabel='Count'>

# %%
#Teste de hipotese
from scipy import stats
t,p1 = scipy.stats.ttest_ind(df_teste.Correlacao_BoostStrapping,df_teste.Correlacao_futura_out_of_sample ,equal_var = False)
if p1>0.05:
    r1 ='True'
else: r1 = 'False'

# %%
#Teste de hipotese
from scipy import stats
t,p2 = scipy.stats.ttest_ind(df_teste.Correlacao_simples_24_meses,df_teste.Correlacao_futura_out_of_sample ,equal_var = False)
if p2>0.05:
    r2 = 'True'
else: r2='False'

# %%
a=df_teste.Correlacao_futura_out_of_sample
b=df_teste.Correlacao_BoostStrapping
c=df_teste.Correlacao_simples_24_meses

v = np.array([[np.mean(a),np.std(a),np.NaN,np.NaN,np.NaN],[np.mean(b),np.std(b),np.mean(df_teste.Correlacao_BoostStrapping_erro),p1,r1],[np.mean(c),np.std(c),np.mean(df_teste.Correlacao_Simples_24_meses_erro),p2,r2]])




df_resultados = pd.DataFrame(v,index = ['Correlacao 12 meses futuros',"Correlacao BootStrapping","Correlacao 24 meses passados"],columns = ['Média','Desvio Padrao','Erro Quadratico Médio','P-valor: Teste de Hiposte Médias Iguais','Resultado Teste'])

# %%
df_resultados
# Out:
#                                            Média         Desvio Padrao  \
# Correlacao 12 meses futuros   0.6355286945537334   0.16524609109187158
# Correlacao BootStrapping      0.5373589291152719  0.048723083892420374
# Correlacao 24 meses passados  0.6092894114811062   0.08974340718324919
#
#                              Erro Quadratico Médio  \
# Correlacao 12 meses futuros                    nan
# Correlacao BootStrapping       0.09816976543846147
# Correlacao 24 meses passados   0.02623928307262714
#
#                              P-valor: Teste de Hiposte Médias Iguais  \
# Correlacao 12 meses futuros                                      nan
# Correlacao BootStrapping                      0.00030071087674599285
# Correlacao 24 meses passados                     0.34715713165760487
#
#                              Resultado Teste
# Correlacao 12 meses futuros              nan
# Correlacao BootStrapping               False
# Correlacao 24 meses passados            True

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('teste_correlacao'+x1+x2+'.xlsx', engine='xlsxwriter')
workbook = writer.book
df_resultados.to_excel(writer,float_format = "%.2f", sheet_name='Graficos',startrow=2,startcol = 11)

worksheet = writer.sheets['Graficos'] 
for i in range(0,6):
    worksheet.insert_image('A'+ str(i*20+1), filename = str(i)+'.png')
workbook=writer.book


df_teste.to_excel(writer,float_format = "%.2f",sheet_name='DadosCorrelacao')
writer.save()
